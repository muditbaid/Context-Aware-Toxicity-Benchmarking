# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.metrics import classification_report

# %%
## transformers==0.45.0
## tokenizers== 0.20.3

base_model = "meta-llama/Llama-3.2-3B-Instruct"
fine_tuned_model = "marcoorasch/llama-3.2-3B-instruct-hatespeech-offensive-classification"

from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from peft import PeftModel
import torch


# Reload tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(fine_tuned_model)

model = AutoModelForCausalLM.from_pretrained(
        fine_tuned_model,
        return_dict=True,
        low_cpu_mem_usage=True,
        torch_dtype=torch.float16,
        device_map="auto",
        trust_remote_code=True,
        offload_buffers=True
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/54.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/927 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]

# %%
# !pip install transformers==4.45.0
# Out:
# Collecting transformers==4.45.0
#   Obtaining dependency information for transformers==4.45.0 from https://files.pythonhosted.org/packages/31/6d/09a57274b45a411e6cc62122a032dd4f7cc6fb9e5323d4376ccc1d74bc56/transformers-4.45.0-py3-none-any.whl.metadata
#   Downloading transformers-4.45.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /home/mb05005/anaconda3/lib/python3.11/site-packages (from transformers==4.45.0) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/mb05005/anaconda3/lib/python3.11/site-packages (from transformers==4.45.0) (0.29.1)
# Requirement already satisfied: numpy>=1.17 in /home/mb05005/anaconda3/lib/python3.11/site-packages (from transformers==4.45.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/mb05005/anaconda3/lib/python3.11/site-packages (from transformers==4.45.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/mb05005/anaconda3/lib/python3.11/site-packages (from transformers==4.45.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/mb05005/anaconda3/lib/python3.11/site-packages (from transformers==4.45.0) (2024.11.6)
# Requirement already satisfied: requests in /home/mb05005/anaconda3/lib/python3.11/site-packages (from transformers==4.45.0) (2.32.3)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.45.0)
#   Obtaining dependency information for tokenizers<0.21,>=0.20 from https://files.pythonhosted.org/packages/50/f6/2841de926bc4118af996eaf0bdf0ea5b012245044766ffc0347e6c968e63/tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /home/mb05005/anaconda3/lib/python3.11/site-packages (from transformers==4.45.0) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /home/mb05005/anaconda3/lib/python3.11/site-packages (from transformers==4.45.0) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/mb05005/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.0) (2024.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/mb05005/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mb05005/anaconda3/lib/python3.11/site-packages (from requests->transformers==4.45.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/mb05005/anaconda3/lib/python3.11/site-packages (from requests->transformers==4.45.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mb05005/anaconda3/lib/python3.11/site-packages (from requests->transformers==4.45.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mb05005/anaconda3/lib/python3.11/site-packages (from requests->transformers==4.45.0) (2024.12.14)
# Downloading transformers-4.45.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 46.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Using cached tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.49.0
#     Uninstalling transformers-4.49.0:
#       Successfully uninstalled transformers-4.49.0
# Successfully installed tokenizers-0.20.3 transformers-4.45.0

# %%
import tokenizers
import transformers

print("Tokenizers version:", tokenizers.__version__)
print("Transformers version:", transformers.__version__)
# Out:
# Tokenizers version: 0.20.3
# Transformers version: 4.45.0

# %%
text = "You are a pig!"

# %%
prompt = f"""Classify the text into Hatespeech, Offensive, Normal and return the answer as the corresponding label.
text: {text}
label: """.strip()

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=2,
    temperature=0.1,
    pad_token_id=tokenizer.eos_token_id,
    torch_dtype=torch.float16,
    device_map="gpu"
)

outputs = pipe(prompt, max_new_tokens=2, do_sample=True, temperature=0.1, pad_token_id=tokenizer.eos_token_id)
print(outputs[0]["generated_text"].split("label: ")[-1].strip())
# Out:
# Offensive

# %%
def generate_test_prompt(data_point,colname):
    return f"""
            Classify the text into Hatespeech, Offensive, Normal and return the answer as the corresponding label.
            text: {data_point[colname]}
            label: """.strip()

# %%
def predict(test, model, tokenizer, colname):
    y_pred = []
    labels = ["Hate", "Offensive", "Normal"]
    
    for i in tqdm(range(len(test))):
        prompt = test.iloc[i][colname]
        # pipe = pipeline(task="text-generation", 
        #                 model=model, 
        #                 tokenizer=tokenizer, 
        #                 max_new_tokens=2, 
        #                 temperature=0.1)
        
        result = pipe(prompt)
        answer = result[0]['generated_text'].split("label:")[-1].strip()
        
        # Determine the predicted category
        for label in labels:
            if label.lower() in answer.lower():
                y_pred.append(label)
                break
        else:
            y_pred.append("none")
    
    return y_pred

# %% [markdown]
# ### TweetOffensive

# %%
from datasets import load_dataset

ds = load_dataset("cardiffnlp/tweet_eval", "offensive")
# Out:
# README.md:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/1.02M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/93.7k [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/122k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/11916 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/860 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1324 [00:00<?, ? examples/s]

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 11916
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 860
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 1324
#     })
# })

# %%
tweetoff = pd.concat([ds['train'].to_pandas(),ds['test'].to_pandas(),ds['validation'].to_pandas()])
tweetoff.head()
# Out:
#                                                 text  label
# 0  @user Bono... who cares. Soon people will unde...      0
# 1  @user Eight years the republicans denied obama...      1
# 2  @user Get him some line help. He is gonna be j...      0
# 3                @user @user She is great. Hi Fiona!      0
# 4  @user She has become a parody unto herself? Sh...      1

# %%
prompts = pd.DataFrame(tweetoff.apply(generate_test_prompt, axis=1), columns=["text"])
prompts.head()
# Out:
#                                                 text
# 0  Classify the text into Hatespeech, Offensive, ...
# 1  Classify the text into Hatespeech, Offensive, ...
# 2  Classify the text into Hatespeech, Offensive, ...
# 3  Classify the text into Hatespeech, Offensive, ...
# 4  Classify the text into Hatespeech, Offensive, ...

# %%
prompts.iloc[2,0]
# Out:
# 'Classify the text into Hatespeech, Offensive, Normal and return the answer as the corresponding label.\n            text: @user Get him some line help. He is gonna be just fine. As the game went on you could see him progressing more with his reads. He brought what has been missing. The deep ball presence. Now he just needs a little more time\n            label:'

# %%
pred = predict(prompts, model, tokenizer)
pred[:5]
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation. 8.79it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation. 9.76it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.80it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.90it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.21it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.35it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.24it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.13it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.01it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.67it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.21it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.04it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation. 9.90it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation. 9.93it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.93it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.73it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.65it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.31it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.83it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.90it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.65it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.07it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.62it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.05it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.05it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.48it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.75it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.46it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.97it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.16it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.37it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.57it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.42it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.84it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.27it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.20it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.69it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.28it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.71it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.08it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.46it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.00it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.35it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.80it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.91it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.34it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.91it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.06it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.24it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.09it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.79it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.37it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.06it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.64it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.50it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.43it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.34it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.57it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.93it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.60it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.29it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.00it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.74it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.62it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.62it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.35it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.23it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.45it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.05it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.78it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.00it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.33it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.14it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.85it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.39it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.78it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.06it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.92it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.07it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.11it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.86it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.45it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.00it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.67it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.23it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.03it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.45it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.34it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.10it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.53it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.19it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.08it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.61it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.88it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.69it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.16it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.53it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.15it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.24it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.00it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.49it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.93it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.61it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.20it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.01it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.69it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.23it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.58it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.65it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.84it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.39it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.96it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.91it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.97it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.64it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.82it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.35it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.85it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.37it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.98it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.08it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.77it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.95it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.47it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.87it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.19it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.58it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.72it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.00it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.41it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.14it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.18it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.15it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.88it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.72it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.00it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.72it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.75it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.92it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.67it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.38it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.84it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.22it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.78it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.35it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.62it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.12it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.29it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.92it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.89it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.82it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.33it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.21it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.64it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.99it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.80it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.45it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.79it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.75it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.15it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.91it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.14it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.57it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.94it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.93it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.22it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.88it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.56it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.18it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.34it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.90it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.70it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.00it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.37it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.67it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.91it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.14.00it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.25it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.35it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.93it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.39it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.69it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.10it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.23it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.01it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.93it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.30it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.47it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.57it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.56it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.61it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.12it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.67it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.56it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.53it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.94it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.97it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.74it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.59it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.64it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.16it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.85it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.82it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.10it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.74it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.22it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.04it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.46it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.87it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.20it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.36it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.62it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.72it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.92it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.48it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.52it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.16it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.65it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.87it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.51it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.38it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.86it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.39it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.82it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.55it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.85it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.91it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.88it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.28it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.67it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.76it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.39it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.63it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.89it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.36it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.97it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.91it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.56it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.53it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.38it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.06it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.65it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.53it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.81it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.19it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.25it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.52it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.31it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.82it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.28it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.62it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.79it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.98it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.47it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.61it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.03it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.36it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.45it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.32it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.42it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.71it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.49it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.36it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.94it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.59it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.96it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.12it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.70it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.28it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.28it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.76it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.21it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.28it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.69it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.08it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.12it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.04it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.16it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.11it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.46it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.26it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.62it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.68it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.41it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.26it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.73it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.15it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.29it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.78it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.03it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.81it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.97it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.42it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.44it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.11it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.73it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.21it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.05it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.91it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.88it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.82it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.40it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.88it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.78it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.18it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.79it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.27it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.69it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.80it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.37it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.86it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.60it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.39it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.66it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.83it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# ...
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.43it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.42it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.55it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.47it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.36it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.32it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.62it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.87it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.59it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.84it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.05it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.21it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.39it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.23it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.27it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.82it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.45it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.92it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.22it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.04it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.56it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.03it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.21it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.39it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.26it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.14it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.76it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.76it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.33it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.69it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.19it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.18it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.68it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.54it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.02it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.76it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.14.16it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.58it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.00it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.58it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.10.81it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.74it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.74it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.57it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.13it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.07it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.99it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.68it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.77it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.38it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.65it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.36it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.92it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.32it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.62it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.77it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.42it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.78it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.99it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.02it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.45it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.68it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.21it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.54it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.71it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.85it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.62it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.40it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.85it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.38it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.06it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.00it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.11.79it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.65it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.90it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.46it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.12it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.17it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.98it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.12it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.04it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.39it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.62it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.74it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.14.12it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.14.22it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.47it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.41it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.81it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.32it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.88it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.14.16it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.14.46it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.55it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.80it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.14.17it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.11it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.61it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.01it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.41it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.00it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.36it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.72it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.13.90it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.12.96it/s]

# %%
pred[:5]
# Out:
# ['Normal', 'Normal', 'Normal', 'Normal', 'Offensive']

# %%
tweetoff['preiction'] = pred
tweetoff['prediction'].value_counts()
# Out:
# prediction
# Normal       11151
# Offensive     2940
# Hate             9
# Name: count, dtype: int64

# %%
tweetoff['pred_label'] = tweetoff['preiction'].map({'Normal':0,'Hate':0,'Offensive':1})
tweetoff.head()
# Out:
#                                                                                                                                                                                                                             text  \
# 0                               @user Bono... who cares. Soon people will understand that they gain nothing from following a phony celebrity. Become a Leader of your people instead or help and support your fellow countrymen.
# 1                                                                                                              @user Eight years the republicans denied obama’s picks. Breitbarters outrage is as phony as their fake president.
# 2  @user Get him some line help. He is gonna be just fine. As the game went on you could see him progressing more with his reads. He brought what has been missing. The deep ball presence. Now he just needs a little more time
# 3                                                                                                                                                                                            @user @user She is great. Hi Fiona!
# 4                                   @user She has become a parody unto herself? She has certainly taken some heat for being such an....well idiot. Could be optic too  Who know with Liberals  They're all optics.  No substance
#
#    label  preiction  pred_label
# 0      0     Normal           0
# 1      1     Normal           0
# 2      0     Normal           0
# 3      0     Normal           0
# 4      1  Offensive           1

# %%
print(classification_report(tweetoff['label'],tweetoff['pred_label'],target_names=['Not Offensive','Offensive']))
# Out:
#                precision    recall  f1-score   support
#
# Not Offensive       0.75      0.89      0.82      9460
#     Offensive       0.64      0.41      0.50      4640
#
#      accuracy                           0.73     14100
#     macro avg       0.70      0.65      0.66     14100
#  weighted avg       0.72      0.73      0.71     14100

# %%
print(tweetoff['label'].value_counts())
print(tweetoff['pred_label'].value_counts())
# Out:
# label
# 0    9460
# 1    4640
# Name: count, dtype: int64
# pred_label
# 0    11160
# 1     2940
# Name: count, dtype: int64

# %%
tweetoff.to_csv("TweetOffensive_llama.csv",index=False)

# %% [markdown]
# ### OffensiveLang

# %%
offlang = pd.read_csv("OffensiveLang/OffensiveLang.csv")
offlang.head()
# Out:
#                                                                                 Text  \
# 0      Your recent performances are lacking the spark that once defined your career.
# 1     I heard your agent is struggling to find you quality roles. Any truth to that?
# 2  Your character lacked depth; it felt like a caricature rather than a real person.
# 3   You were overshadowed by the set design; it was more memorable than your acting.
# 4                            You're not as talented as [another actor] in that role.
#
#      Category Target Group Final Annotation OpenAI_Annotation     Annotator1  \
# 0  Occupation        Actor        Offensive     Not Offensive  Not Offensive
# 1  Occupation        Actor        Offensive         Offensive      Offensive
# 2  Occupation        Actor        Offensive     Not Offensive      Offensive
# 3  Occupation        Actor        Offensive         Offensive      Offensive
# 4  Occupation        Actor        Offensive         Offensive      Offensive
#
#       Annotator2     Annotator3
# 0      Offensive      Offensive
# 1      Offensive      Offensive
# 2      Offensive      Offensive
# 3      Offensive  Not Offensive
# 4  Not Offensive      Offensive

# %%
offlang_prompts = pd.DataFrame(offlang.apply(generate_test_prompt, axis=1, args=("Text",)), columns=["Text"])
offlang_prompts.head()
# Out:
#                                                                                                                                                                                                                               Text
# 0      Classify the text into Hatespeech, Offensive, Normal and return the answer as the corresponding label.\n            text: Your recent performances are lacking the spark that once defined your career.\n            label:
# 1     Classify the text into Hatespeech, Offensive, Normal and return the answer as the corresponding label.\n            text: I heard your agent is struggling to find you quality roles. Any truth to that?\n            label:
# 2  Classify the text into Hatespeech, Offensive, Normal and return the answer as the corresponding label.\n            text: Your character lacked depth; it felt like a caricature rather than a real person.\n            label:
# 3   Classify the text into Hatespeech, Offensive, Normal and return the answer as the corresponding label.\n            text: You were overshadowed by the set design; it was more memorable than your acting.\n            label:
# 4                            Classify the text into Hatespeech, Offensive, Normal and return the answer as the corresponding label.\n            text: You're not as talented as [another actor] in that role.\n            label:

# %%
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=2,
    temperature=0.1,
    pad_token_id=tokenizer.eos_token_id,
    torch_dtype=torch.float16,
    device_map="gpu"
)

# %%
offlang_pred = predict(offlang_prompts, model, tokenizer,colname="Text")
offlang_pred[:5]
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 100%|███████████████████████████████████████| 8270/8270 [10:00<00:00, 13.77it/s]
# ['Normal', 'Normal', 'Normal', 'Normal', 'Normal']

# %%
offlang['prediction'] = offlang_pred
offlang['pred_label'] = offlang['prediction'].apply(lambda x: 1 if x=='Offensive' else 0)
offlang.head()
# Out:
#                                                                                 Text  \
# 0      Your recent performances are lacking the spark that once defined your career.
# 1     I heard your agent is struggling to find you quality roles. Any truth to that?
# 2  Your character lacked depth; it felt like a caricature rather than a real person.
# 3   You were overshadowed by the set design; it was more memorable than your acting.
# 4                            You're not as talented as [another actor] in that role.
#
#      Category Target Group Final Annotation OpenAI_Annotation     Annotator1  \
# 0  Occupation        Actor        Offensive     Not Offensive  Not Offensive
# 1  Occupation        Actor        Offensive         Offensive      Offensive
# 2  Occupation        Actor        Offensive     Not Offensive      Offensive
# 3  Occupation        Actor        Offensive         Offensive      Offensive
# 4  Occupation        Actor        Offensive         Offensive      Offensive
#
#       Annotator2     Annotator3 prediction  pred_label
# 0      Offensive      Offensive     Normal           0
# 1      Offensive      Offensive     Normal           0
# 2      Offensive      Offensive     Normal           0
# 3      Offensive  Not Offensive     Normal           0
# 4  Not Offensive      Offensive     Normal           0

# %%
offlang['true_label'] = offlang['Final Annotation'].apply(lambda x: 1 if x=="Offensive" else 0)

# %%
print(classification_report(offlang['true_label'],offlang['pred_label'],target_names=['Not Offensive','Offensive']))
# Out:
#                precision    recall  f1-score   support
#
# Not Offensive       0.22      0.95      0.36      1748
#     Offensive       0.88      0.09      0.16      6522
#
#      accuracy                           0.27      8270
#     macro avg       0.55      0.52      0.26      8270
#  weighted avg       0.74      0.27      0.20      8270

# %%
offlang.to_csv("offlang_llama.csv",index=False)

# %% [markdown]
# ### TDavidson

# %%
from datasets import load_dataset

ds = load_dataset("tdavidson/hate_speech_offensive")

# %%
td = ds['train'].to_pandas()
td.head()
# Out:
#    count  hate_speech_count  offensive_language_count  neither_count  class  \
# 0      3                  0                         0              3      2
# 1      3                  0                         3              0      1
# 2      3                  0                         3              0      1
# 3      3                  0                         2              1      1
# 4      6                  0                         6              0      1
#
#                                                                                                                                           tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't complain about cleaning up your house. &amp; as a man you should always take the trash out...
# 1                                                         !!!!! RT @mleew17: boy dats cold...tyga dwn bad for cuffin dat hoe in the 1st place!!
# 2                      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby4life: You ever fuck a bitch and she start to cry? You be confused as shit
# 3                                                                                !!!!!!!!! RT @C_G_Anderson: @viva_based she look like a tranny
# 4     !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you hear about me might be true or it might be faker than the bitch who told it to ya &#57361;

# %%
td_prompts = pd.DataFrame(td.apply(generate_test_prompt, axis=1, args=("tweet",)), columns=["tweet"])
td_prompts.head()
# Out:
#                                                                                                                                                                                                                                                                                         tweet
# 0  Classify the text into Hatespeech, Offensive, Normal and return the answer as the corresponding label.\n            text: !!! RT @mayasolovely: As a woman you shouldn't complain about cleaning up your house. &amp; as a man you should always take the trash out...\n            label:
# 1                                                         Classify the text into Hatespeech, Offensive, Normal and return the answer as the corresponding label.\n            text: !!!!! RT @mleew17: boy dats cold...tyga dwn bad for cuffin dat hoe in the 1st place!!\n            label:
# 2                      Classify the text into Hatespeech, Offensive, Normal and return the answer as the corresponding label.\n            text: !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby4life: You ever fuck a bitch and she start to cry? You be confused as shit\n            label:
# 3                                                                                Classify the text into Hatespeech, Offensive, Normal and return the answer as the corresponding label.\n            text: !!!!!!!!! RT @C_G_Anderson: @viva_based she look like a tranny\n            label:
# 4     Classify the text into Hatespeech, Offensive, Normal and return the answer as the corresponding label.\n            text: !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you hear about me might be true or it might be faker than the bitch who told it to ya &#57361;\n            label:

# %%
td_pred = predict(td_prompts, model, tokenizer,colname="tweet")
td_pred[:5]
# Out:
# 100%|█████████████████████████████████████| 24783/24783 [30:14<00:00, 13.66it/s]
# ['Normal', 'Offensive', 'Offensive', 'Offensive', 'Offensive']

# %%
td['prediction'] = td_pred
td['pred_label'] = td['prediction'].apply(lambda x: 1 if x=='Offensive' else 0)
td['true_label'] = td['class'].apply(lambda x: 1 if x==1 else 0)
print(classification_report(td['true_label'],td['pred_label'],target_names=['Not Offensive','Offensive']))
# Out:
#                precision    recall  f1-score   support
#
# Not Offensive       0.88      0.65      0.74      5593
#     Offensive       0.90      0.97      0.94     19190
#
#      accuracy                           0.90     24783
#     macro avg       0.89      0.81      0.84     24783
#  weighted avg       0.90      0.90      0.89     24783

# %%
td.to_csv('TDavidson_llama.csv',index=False)
