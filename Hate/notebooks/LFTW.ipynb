# %%
# !git clone https://github.com/bvidgen/Dynamically-Generated-Hate-Speech-Dataset.git
# Out:
# Cloning into 'Dynamically-Generated-Hate-Speech-Dataset'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 76 (delta 27), reused 0 (delta 0), pack-reused 19 (from 1)
# Unpacking objects: 100% (76/76), 5.84 MiB | 3.55 MiB/s, done.

# %%
import pandas as pd
import numpy as np

# %%
# !pwd
# Out:
# /home/mb05005/mudit/Hate Speech

# %%
# %cd Dynamically-Generated-Hate-Speech-Dataset
# Out:
# /home/mb05005/mudit/Hate Speech/Dynamically-Generated-Hate-Speech-Dataset

# %%
# !ls
# Out:
# 'Dynamically Generated Hate Dataset - annotation guidelines.pdf'
# 'Dynamically Generated Hate Dataset v0.2.2.csv'
# 'Dynamically Generated Hate Dataset v0.2.3.csv'
#  README.md

# %%
df = pd.read_csv('Dynamically Generated Hate Dataset v0.2.2.csv')

# %%
df['round.base'].value_counts()
# Out:
# round.base
# 1    11157
# 4    10152
# 2     9996
# 3     9950
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#    Unnamed: 0    acl.id  X1  \
# 0           1      acl1   1
# 1           2     acl10   2
# 2           3    acl100   3
# 3           4   acl1000   4
# 4           5  acl10000   5
# 5           6  acl10001   6
# 6           7  acl10002   7
# 7           8  acl10003   8
# 8           9  acl10004   9
# 9          10  acl10005  10
#
#                                                 text    label      type  \
# 0                                dalits are lowlives     hate  notgiven
# 1             gay people are a burden to our society     hate  notgiven
# 2                              Arabs are not welcome     hate  notgiven
# 3  I'm not saying we should actually eliminate he...     hate  notgiven
# 4                       bananas are for black people     hate  notgiven
# 5                          asian people are the shit  nothate      none
# 6  women can not reproduce kids but men can in al...     hate  notgiven
# 7                i hate wearing black in the summer!  nothate      none
# 8               Who cares what Chinese people think?     hate  notgiven
# 9         i try to punch a letter box when i see one     hate  notgiven
#
#      target     level  split  round.base   annotator round acl.id.matched
# 0  notgiven  original  train           1  GNZuCtwed3     1            NaN
# 1  notgiven  original  train           1  GNZuCtwed3     1            NaN
# 2  notgiven  original  train           1  vDe7GN0NrL     1            NaN
# 3  notgiven  original  train           1  oemYWm1Tjg     1            NaN
# 4  notgiven  original   test           1  QiOKkCi7F8     1            NaN
# 5      none  original   test           1  GNZuCtwed3     1            NaN
# 6  notgiven  original   test           1  vDe7GN0NrL     1            NaN
# 7      none  original   test           1  LqLKTtrOmx     1            NaN
# 8  notgiven  original   test           1  CAgNlUizNm     1            NaN
# 9  notgiven  original   test           1  LqLKTtrOmx     1            NaN

# %%
len(df)
# Out:
# 41255

# %%
data = df[(df['round.base']==4) & ((df['split']=='test') | (df['split']=='dev'))]

# %%
data.head(10)
# Out:
#        Unnamed: 0    acl.id     X1  \
# 32475       32476  acl39226  32476
# 32476       32477  acl39227  32477
# 32477       32478  acl39228  32478
# 32478       32479  acl39229  32479
# 32480       32481  acl39230  32481
# 32481       32482  acl39231  32482
# 32482       32483  acl39232  32483
# 32483       32484  acl39233  32484
# 32484       32485  acl39234  32485
# 32485       32486  acl39235  32486
#
#                                                     text    label  type  \
# 32475  You don't necessarily have to believe that all...  nothate  none
# 32476  In Finland apparently 'Middle Easterners and N...  nothate  none
# 32477  The men who committed the sexual assaults in k...  nothate  none
# 32478  The most interesting point to consider perhaps...  nothate  none
# 32480  Why would you say that about him? that Adolf H...  nothate  none
# 32481  The African continent is overall prone to para...  nothate  none
# 32482  The last common ancestor between Europeans and...  nothate  none
# 32483  the problem the horticulturalists don;t want t...  nothate  none
# 32484  There is a clear difference between referees a...  nothate  none
# 32485  The military here all want to live in their bu...  nothate  none
#
#       target         level split  round.base   annotator round acl.id.matched
# 32475   none  perturbation  test           4  zUUAkSVCEa    4b       acl40127
# 32476   none  perturbation  test           4  zUUAkSVCEa    4b       acl31135
# 32477   none  perturbation  test           4  zUUAkSVCEa    4b       acl31143
# 32478   none  perturbation  test           4  gbEGjSAk6r    4b       acl31183
# 32480   none  perturbation  test           4  gbEGjSAk6r    4b       acl31203
# 32481   none  perturbation  test           4  gbEGjSAk6r    4b       acl31206
# 32482   none  perturbation  test           4  gbEGjSAk6r    4b       acl31216
# 32483   none  perturbation  test           4  zUUAkSVCEa    4b       acl31220
# 32484   none  perturbation  test           4  zUUAkSVCEa    4b       acl31245
# 32485   none  perturbation  test           4  zUUAkSVCEa    4b       acl31248

# %%
data.drop(columns=['acl.id.matched','X1'],axis=1,inplace=True)
# Out:
# /tmp/ipykernel_719265/2396051185.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=['acl.id.matched','X1'],axis=1,inplace=True)

# %%
data.drop(data.columns[data.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
# Out:
# /tmp/ipykernel_719265/4130926354.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(data.columns[data.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
data.head()
# Out:
#          acl.id                                               text    label  \
# 32475  acl39226  You don't necessarily have to believe that all...  nothate
# 32476  acl39227  In Finland apparently 'Middle Easterners and N...  nothate
# 32477  acl39228  The men who committed the sexual assaults in k...  nothate
# 32478  acl39229  The most interesting point to consider perhaps...  nothate
# 32480  acl39230  Why would you say that about him? that Adolf H...  nothate
#
#        type target         level split  round.base   annotator round
# 32475  none   none  perturbation  test           4  zUUAkSVCEa    4b
# 32476  none   none  perturbation  test           4  zUUAkSVCEa    4b
# 32477  none   none  perturbation  test           4  zUUAkSVCEa    4b
# 32478  none   none  perturbation  test           4  gbEGjSAk6r    4b
# 32480  none   none  perturbation  test           4  gbEGjSAk6r    4b

# %%
len(data)
# Out:
# 2030

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from tqdm import tqdm
from datasets import load_dataset

# Load the tweet_hate dataset
# ds = load_dataset("cardiffnlp/super_tweeteval", "tweet_hate")

# # Convert the 'test' split to a pandas DataFrame
# df = pd.DataFrame(ds['test'])

# Initialize label mappings
label_mappings = {
    "facebook_roberta": {0: 'Neutral', 1: 'Hate'},
    "hatexplain": {0: 'Hate', 1: 'Neutral', 2: 'Offensive'},
    "distilroberta": {0: 'Hate', 1: 'Offensive', 2: 'Neutral'},
    "cardiff_roberta": {0: "hate_gender", 1: "hate_race", 2: "hate_sexuality",
                        3: "hate_religion", 4: "hate_origin", 5: "hate_disability",
                        6: "hate_age", 7: "Neutral"},
    "dehatebert": {0: 'Neutral', 1: 'Hate'}
}

# Initialize the list of models
models = {
    "facebook_roberta": "facebook/roberta-hate-speech-dynabench-r4-target",
    "hatexplain": "Hate-speech-CNERG/bert-base-uncased-hatexplain",
    "distilroberta": "badmatr11x/distilroberta-base-offensive-hateful-speech-text-multiclassification",
    "cardiff_roberta": "cardiffnlp/twitter-roberta-large-hate-latest",
    "dehatebert": "Hate-speech-CNERG/dehatebert-mono-english",
}
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Function to run each model and get predictions, with offloading after each model
def run_model(model_name, model_path, text_list):
    print(f"Running model: {model_name}")

    # Tokenize the input text and move it to the GPU
    tokenizer = AutoTokenizer.from_pretrained(model_path)

    # Load the model and tokenizer and Move the model to the GPU
    model = AutoModelForSequenceClassification.from_pretrained(model_path)
    model = model.to(device)

    def print_memory_usage(message):
        allocated_memory = torch.cuda.memory_allocated(device) / 1024**3  # Convert to GB
        cached_memory = torch.cuda.memory_reserved(device) / 1024**3  # Convert to GB
        print(f"{message}: Allocated: {allocated_memory:.2f} GB, Cached: {cached_memory:.2f} GB")

    predictions_list = []
    batch_size = 32
    for i in range(0, len(text_list), batch_size):
        batch_text = text_list[i:i + batch_size]
        inputs = tokenizer(batch_text, padding=True, truncation=True, return_tensors="pt").to(device)

        # inputs = tokenizer(text_list, padding=True, truncation=True, return_tensors="pt")
        inputs = inputs.to(device)

        print_memory_usage("Before running model")

        # Run inference with no gradients
        with torch.no_grad():
            outputs = model(**inputs)

        # Get the predicted probabilities and labels
        probabilities = torch.softmax(outputs.logits, dim=-1)
        predictions = torch.argmax(probabilities, dim=-1)

        print_memory_usage("After running model")

        # Convert predictions to a list of label names
        predictions_list.extend(predictions.tolist())


    # Offload the model to the CPU
    model = model.to('cpu')
    torch.cuda.empty_cache()  # Clear GPU cache after offloading
    print_memory_usage("After offloading model to CPU and clearing cache")
    label_list = [label_mappings[model_name][pred] for pred in predictions_list]
    return label_list

# Run all models and append the predictions as new columns to the DataFrame
for model_name, model_path in tqdm(models.items(), desc="Running models"):
    data[model_name] = run_model(model_name, model_path, data['text'].tolist())

# Display the updated DataFrame with model predictions
data.head()
# Out:
# Running models:   0%|                                                                                                                                                                | 0/5 [00:00<?, ?it/s]
# Running model: facebook_roberta
# Before running model: Allocated: 0.47 GB, Cached: 0.52 GB
# After running model: Allocated: 0.47 GB, Cached: 0.66 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.66 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 0.98 GB
# Before running model: Allocated: 0.47 GB, Cached: 0.98 GB
# After running model: Allocated: 0.47 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.17 GB
# After running model: Allocated: 0.47 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.17 GB
# After running model: Allocated: 0.47 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.17 GB
# After running model: Allocated: 0.47 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.17 GB
# After running model: Allocated: 0.47 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.17 GB
# After running model: Allocated: 0.47 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.17 GB
# After running model: Allocated: 0.47 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.17 GB
# After running model: Allocated: 0.47 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.17 GB
# After running model: Allocated: 0.47 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.17 GB
# After running model: Allocated: 0.47 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.17 GB
# After running model: Allocated: 0.47 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.17 GB
# After running model: Allocated: 0.47 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.17 GB
# After running model: Allocated: 0.47 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.17 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# Before running model: Allocated: 0.47 GB, Cached: 1.38 GB
# After running model: Allocated: 0.47 GB, Cached: 1.38 GB
# /tmp/ipykernel_719265/3716599250.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[model_name] = run_model(model_name, model_path, data['text'].tolist())
# Running models:  20%|██████████████████████████████▍                                                                                                                         | 1/5 [00:06<00:27,  6.79s/it]
# After offloading model to CPU and clearing cache: Allocated: 0.01 GB, Cached: 0.02 GB
# Running model: hatexplain
# BertSdpaSelfAttention is used but `torch.nn.functional.scaled_dot_product_attention` does not support non-absolute `position_embedding_type` or `output_attentions=True` or `head_mask`. Falling back to the manual attention implementation, but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.
# Before running model: Allocated: 0.42 GB, Cached: 0.46 GB
# After running model: Allocated: 0.57 GB, Cached: 0.76 GB
# Before running model: Allocated: 0.57 GB, Cached: 0.76 GB
# After running model: Allocated: 1.53 GB, Cached: 2.19 GB
# Before running model: Allocated: 1.53 GB, Cached: 2.19 GB
# After running model: Allocated: 0.59 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.59 GB, Cached: 2.19 GB
# After running model: Allocated: 0.85 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.85 GB, Cached: 2.19 GB
# After running model: Allocated: 0.70 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.70 GB, Cached: 2.19 GB
# After running model: Allocated: 0.52 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.52 GB, Cached: 2.19 GB
# After running model: Allocated: 0.59 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.59 GB, Cached: 2.19 GB
# After running model: Allocated: 0.60 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.60 GB, Cached: 2.19 GB
# After running model: Allocated: 0.75 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.75 GB, Cached: 2.19 GB
# After running model: Allocated: 0.74 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.74 GB, Cached: 2.19 GB
# After running model: Allocated: 0.76 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.76 GB, Cached: 2.19 GB
# After running model: Allocated: 0.55 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.55 GB, Cached: 2.19 GB
# After running model: Allocated: 0.56 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.56 GB, Cached: 2.19 GB
# After running model: Allocated: 0.66 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.66 GB, Cached: 2.19 GB
# After running model: Allocated: 0.82 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.82 GB, Cached: 2.19 GB
# After running model: Allocated: 0.68 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.68 GB, Cached: 2.19 GB
# After running model: Allocated: 0.52 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.52 GB, Cached: 2.19 GB
# After running model: Allocated: 0.47 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.47 GB, Cached: 2.19 GB
# After running model: Allocated: 0.89 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.89 GB, Cached: 2.19 GB
# After running model: Allocated: 0.83 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.83 GB, Cached: 2.19 GB
# After running model: Allocated: 0.58 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.58 GB, Cached: 2.19 GB
# After running model: Allocated: 0.58 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.58 GB, Cached: 2.19 GB
# After running model: Allocated: 0.85 GB, Cached: 2.19 GB
# Before running model: Allocated: 0.85 GB, Cached: 2.19 GB
# After running model: Allocated: 1.11 GB, Cached: 2.71 GB
# Before running model: Allocated: 1.11 GB, Cached: 2.71 GB
# After running model: Allocated: 0.91 GB, Cached: 2.78 GB
# Before running model: Allocated: 0.91 GB, Cached: 2.78 GB
# After running model: Allocated: 0.55 GB, Cached: 2.78 GB
# Before running model: Allocated: 0.55 GB, Cached: 2.78 GB
# After running model: Allocated: 1.40 GB, Cached: 2.78 GB
# Before running model: Allocated: 1.40 GB, Cached: 2.78 GB
# After running model: Allocated: 0.70 GB, Cached: 2.78 GB
# Before running model: Allocated: 0.70 GB, Cached: 2.78 GB
# After running model: Allocated: 0.80 GB, Cached: 2.78 GB
# Before running model: Allocated: 0.80 GB, Cached: 2.78 GB
# After running model: Allocated: 0.74 GB, Cached: 2.78 GB
# Before running model: Allocated: 0.74 GB, Cached: 2.78 GB
# After running model: Allocated: 1.11 GB, Cached: 2.78 GB
# Before running model: Allocated: 1.11 GB, Cached: 2.78 GB
# After running model: Allocated: 1.23 GB, Cached: 3.26 GB
# Before running model: Allocated: 1.23 GB, Cached: 3.26 GB
# After running model: Allocated: 0.76 GB, Cached: 3.26 GB
# Before running model: Allocated: 0.76 GB, Cached: 3.26 GB
# After running model: Allocated: 0.61 GB, Cached: 3.26 GB
# Before running model: Allocated: 0.61 GB, Cached: 3.26 GB
# After running model: Allocated: 0.78 GB, Cached: 3.26 GB
# Before running model: Allocated: 0.78 GB, Cached: 3.26 GB
# After running model: Allocated: 1.64 GB, Cached: 4.70 GB
# Before running model: Allocated: 1.64 GB, Cached: 4.70 GB
# After running model: Allocated: 1.12 GB, Cached: 4.70 GB
# Before running model: Allocated: 1.12 GB, Cached: 4.70 GB
# After running model: Allocated: 0.69 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.69 GB, Cached: 4.70 GB
# After running model: Allocated: 1.10 GB, Cached: 4.70 GB
# Before running model: Allocated: 1.10 GB, Cached: 4.70 GB
# After running model: Allocated: 0.63 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.63 GB, Cached: 4.70 GB
# After running model: Allocated: 0.57 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.57 GB, Cached: 4.70 GB
# After running model: Allocated: 0.69 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.69 GB, Cached: 4.70 GB
# After running model: Allocated: 0.62 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.62 GB, Cached: 4.70 GB
# After running model: Allocated: 0.54 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.54 GB, Cached: 4.70 GB
# After running model: Allocated: 0.79 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.79 GB, Cached: 4.70 GB
# After running model: Allocated: 0.59 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.59 GB, Cached: 4.70 GB
# After running model: Allocated: 0.61 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.61 GB, Cached: 4.70 GB
# After running model: Allocated: 0.60 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.60 GB, Cached: 4.70 GB
# After running model: Allocated: 1.61 GB, Cached: 4.70 GB
# Before running model: Allocated: 1.61 GB, Cached: 4.70 GB
# After running model: Allocated: 0.66 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.66 GB, Cached: 4.70 GB
# After running model: Allocated: 0.73 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.73 GB, Cached: 4.70 GB
# After running model: Allocated: 0.72 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.72 GB, Cached: 4.70 GB
# After running model: Allocated: 0.73 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.73 GB, Cached: 4.70 GB
# After running model: Allocated: 1.15 GB, Cached: 4.70 GB
# Before running model: Allocated: 1.15 GB, Cached: 4.70 GB
# After running model: Allocated: 0.68 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.68 GB, Cached: 4.70 GB
# After running model: Allocated: 0.85 GB, Cached: 4.70 GB
# Before running model: Allocated: 0.85 GB, Cached: 4.70 GB
# After running model: Allocated: 1.81 GB, Cached: 6.33 GB
# Before running model: Allocated: 1.81 GB, Cached: 6.33 GB
# After running model: Allocated: 0.78 GB, Cached: 6.33 GB
# Before running model: Allocated: 0.78 GB, Cached: 6.33 GB
# After running model: Allocated: 0.75 GB, Cached: 6.33 GB
# Before running model: Allocated: 0.75 GB, Cached: 6.33 GB
# After running model: Allocated: 0.53 GB, Cached: 6.33 GB
# Before running model: Allocated: 0.53 GB, Cached: 6.33 GB
# After running model: Allocated: 0.65 GB, Cached: 6.33 GB
# Before running model: Allocated: 0.65 GB, Cached: 6.33 GB
# After running model: Allocated: 0.82 GB, Cached: 6.33 GB
# Before running model: Allocated: 0.82 GB, Cached: 6.33 GB
# After running model: Allocated: 0.58 GB, Cached: 6.33 GB
# Before running model: Allocated: 0.58 GB, Cached: 6.33 GB
# After running model: Allocated: 0.52 GB, Cached: 6.33 GB
# /tmp/ipykernel_719265/3716599250.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[model_name] = run_model(model_name, model_path, data['text'].tolist())
# Running models:  40%|████████████████████████████████████████████████████████████▊                                                                                           | 2/5 [00:12<00:19,  6.44s/it]
# After offloading model to CPU and clearing cache: Allocated: 0.11 GB, Cached: 0.28 GB
# Running model: distilroberta
# Before running model: Allocated: 0.32 GB, Cached: 0.42 GB
# After running model: Allocated: 0.32 GB, Cached: 0.46 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.46 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.77 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.77 GB
# After running model: Allocated: 0.32 GB, Cached: 0.96 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.96 GB
# After running model: Allocated: 0.32 GB, Cached: 0.96 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.96 GB
# After running model: Allocated: 0.32 GB, Cached: 0.96 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.96 GB
# After running model: Allocated: 0.32 GB, Cached: 0.96 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.96 GB
# After running model: Allocated: 0.32 GB, Cached: 0.96 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.96 GB
# After running model: Allocated: 0.32 GB, Cached: 0.96 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.96 GB
# After running model: Allocated: 0.32 GB, Cached: 0.96 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.96 GB
# After running model: Allocated: 0.32 GB, Cached: 0.96 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.96 GB
# After running model: Allocated: 0.32 GB, Cached: 0.96 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.96 GB
# After running model: Allocated: 0.32 GB, Cached: 0.96 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.96 GB
# After running model: Allocated: 0.32 GB, Cached: 0.96 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.96 GB
# After running model: Allocated: 0.32 GB, Cached: 0.96 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.96 GB
# After running model: Allocated: 0.32 GB, Cached: 0.96 GB
# Before running model: Allocated: 0.32 GB, Cached: 0.96 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# /tmp/ipykernel_719265/3716599250.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[model_name] = run_model(model_name, model_path, data['text'].tolist())
# Running models:  60%|███████████████████████████████████████████████████████████████████████████████████████████▏                                                            | 3/5 [00:16<00:09,  4.96s/it]
# Before running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After running model: Allocated: 0.32 GB, Cached: 1.17 GB
# After offloading model to CPU and clearing cache: Allocated: 0.01 GB, Cached: 0.02 GB
# Running model: cardiff_roberta
# Before running model: Allocated: 1.33 GB, Cached: 1.34 GB
# After running model: Allocated: 1.33 GB, Cached: 1.54 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.54 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 1.96 GB
# Before running model: Allocated: 1.33 GB, Cached: 1.96 GB
# After running model: Allocated: 1.33 GB, Cached: 2.21 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.21 GB
# After running model: Allocated: 1.33 GB, Cached: 2.21 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.21 GB
# After running model: Allocated: 1.33 GB, Cached: 2.21 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.21 GB
# After running model: Allocated: 1.33 GB, Cached: 2.21 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.21 GB
# After running model: Allocated: 1.33 GB, Cached: 2.21 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.21 GB
# After running model: Allocated: 1.33 GB, Cached: 2.21 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.21 GB
# After running model: Allocated: 1.33 GB, Cached: 2.21 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.21 GB
# After running model: Allocated: 1.33 GB, Cached: 2.21 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.21 GB
# After running model: Allocated: 1.33 GB, Cached: 2.21 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.21 GB
# After running model: Allocated: 1.33 GB, Cached: 2.21 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.21 GB
# After running model: Allocated: 1.33 GB, Cached: 2.21 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.21 GB
# After running model: Allocated: 1.33 GB, Cached: 2.21 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.21 GB
# After running model: Allocated: 1.33 GB, Cached: 2.21 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.21 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# Before running model: Allocated: 1.33 GB, Cached: 2.49 GB
# After running model: Allocated: 1.33 GB, Cached: 2.49 GB
# /tmp/ipykernel_719265/3716599250.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[model_name] = run_model(model_name, model_path, data['text'].tolist())
# Running models:  80%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                              | 4/5 [00:33<00:09,  9.70s/it]
# After offloading model to CPU and clearing cache: Allocated: 0.01 GB, Cached: 0.02 GB
# Running model: dehatebert
# Before running model: Allocated: 0.63 GB, Cached: 0.68 GB
# After running model: Allocated: 0.63 GB, Cached: 0.83 GB
# Before running model: Allocated: 0.63 GB, Cached: 0.83 GB
# After running model: Allocated: 0.63 GB, Cached: 1.18 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.18 GB
# After running model: Allocated: 0.63 GB, Cached: 1.18 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.18 GB
# After running model: Allocated: 0.63 GB, Cached: 1.18 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.18 GB
# After running model: Allocated: 0.63 GB, Cached: 1.18 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.18 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.19 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.19 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.39 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.39 GB
# After running model: Allocated: 0.63 GB, Cached: 1.61 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.61 GB
# After running model: Allocated: 0.63 GB, Cached: 1.61 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.61 GB
# After running model: Allocated: 0.63 GB, Cached: 1.61 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.61 GB
# After running model: Allocated: 0.63 GB, Cached: 1.61 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.61 GB
# After running model: Allocated: 0.63 GB, Cached: 1.61 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.61 GB
# After running model: Allocated: 0.63 GB, Cached: 1.61 GB
# Before running model: Allocated: 0.63 GB, Cached: 1.61 GB
# After running model: Allocated: 0.63 GB, Cached: 1.61 GB
# /tmp/ipykernel_719265/3716599250.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[model_name] = run_model(model_name, model_path, data['text'].tolist())
# Running models: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:39<00:00,  7.91s/it]
# Before running model: Allocated: 0.63 GB, Cached: 1.61 GB
# After running model: Allocated: 0.63 GB, Cached: 1.61 GB
# After offloading model to CPU and clearing cache: Allocated: 0.01 GB, Cached: 0.02 GB
#          acl.id                                               text    label  \
# 32475  acl39226  You don't necessarily have to believe that all...  nothate
# 32476  acl39227  In Finland apparently 'Middle Easterners and N...  nothate
# 32477  acl39228  The men who committed the sexual assaults in k...  nothate
# 32478  acl39229  The most interesting point to consider perhaps...  nothate
# 32480  acl39230  Why would you say that about him? that Adolf H...  nothate
#
#        type target         level split  round.base   annotator round  \
# 32475  none   none  perturbation  test           4  zUUAkSVCEa    4b
# 32476  none   none  perturbation  test           4  zUUAkSVCEa    4b
# 32477  none   none  perturbation  test           4  zUUAkSVCEa    4b
# 32478  none   none  perturbation  test           4  gbEGjSAk6r    4b
# 32480  none   none  perturbation  test           4  gbEGjSAk6r    4b
#
#       facebook_roberta hatexplain distilroberta cardiff_roberta dehatebert
# 32475          Neutral    Neutral       Neutral         Neutral       Hate
# 32476          Neutral    Neutral       Neutral         Neutral    Neutral
# 32477          Neutral    Neutral       Neutral         Neutral    Neutral
# 32478          Neutral    Neutral       Neutral         Neutral    Neutral
# 32480          Neutral    Neutral       Neutral         Neutral    Neutral

# %%
data.to_excel('LFTW_results.xlsx',index=False)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/MyDrive/_Immigration LatinX'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/.shortcut-targets-by-id/15qBLFlUf-o-58bi_3Y6CDVFEEswJT6DT/_Immigration LatinX

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('LFTW_results.xlsx')
data.head()
# Out:
#      acl.id                                               text    label  type  \
# 0  acl39226  You don't necessarily have to believe that all...  nothate  none
# 1  acl39227  In Finland apparently 'Middle Easterners and N...  nothate  none
# 2  acl39228  The men who committed the sexual assaults in k...  nothate  none
# 3  acl39229  The most interesting point to consider perhaps...  nothate  none
# 4  acl39230  Why would you say that about him? that Adolf H...  nothate  none
#
#   target         level split  round.base   annotator round facebook_roberta  \
# 0   none  perturbation  test           4  zUUAkSVCEa    4b          Neutral
# 1   none  perturbation  test           4  zUUAkSVCEa    4b          Neutral
# 2   none  perturbation  test           4  zUUAkSVCEa    4b          Neutral
# 3   none  perturbation  test           4  gbEGjSAk6r    4b          Neutral
# 4   none  perturbation  test           4  gbEGjSAk6r    4b          Neutral
#
#   hatexplain distilroberta cardiff_roberta dehatebert
# 0    Neutral       Neutral         Neutral       Hate
# 1    Neutral       Neutral         Neutral    Neutral
# 2    Neutral       Neutral         Neutral    Neutral
# 3    Neutral       Neutral         Neutral    Neutral
# 4    Neutral       Neutral         Neutral    Neutral

# %%
df = data.copy()
df['label'].replace('nothate','Neutral',inplace=True)
df['label'].replace('hate','Hate',inplace=True)
# Out:
# <ipython-input-9-e5927cd54810>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['label'].replace('nothate','Neutral',inplace=True)
# <ipython-input-9-e5927cd54810>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['label'].replace('hate','Hate',inplace=True)

# %%
# Replace 'Offensive' with 'Hate' in both 'hatexplain' and 'distilroberta' columns
df.replace({'hatexplain': {'Offensive': 'Hate'}, 'distilroberta': {'Offensive': 'Hate'}}, inplace=True)

# %%
df.head()
# Out:
#      acl.id                                               text    label  type  \
# 0  acl39226  You don't necessarily have to believe that all...  Neutral  none
# 1  acl39227  In Finland apparently 'Middle Easterners and N...  Neutral  none
# 2  acl39228  The men who committed the sexual assaults in k...  Neutral  none
# 3  acl39229  The most interesting point to consider perhaps...  Neutral  none
# 4  acl39230  Why would you say that about him? that Adolf H...  Neutral  none
#
#   target         level split  round.base   annotator round facebook_roberta  \
# 0   none  perturbation  test           4  zUUAkSVCEa    4b          Neutral
# 1   none  perturbation  test           4  zUUAkSVCEa    4b          Neutral
# 2   none  perturbation  test           4  zUUAkSVCEa    4b          Neutral
# 3   none  perturbation  test           4  gbEGjSAk6r    4b          Neutral
# 4   none  perturbation  test           4  gbEGjSAk6r    4b          Neutral
#
#   hatexplain distilroberta cardiff_roberta dehatebert
# 0    Neutral       Neutral         Neutral       Hate
# 1    Neutral       Neutral         Neutral    Neutral
# 2    Neutral       Neutral         Neutral    Neutral
# 3    Neutral       Neutral         Neutral    Neutral
# 4    Neutral       Neutral         Neutral    Neutral

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt


# Mapping for hatexplain and distilroberta
label_mapping = {'Hate': 0,'Neutral': 1}

# Convert labels to numerical values for matching models
df['true_label'] = df['label'].map(label_mapping)
df['hatexplain_numeric'] = df['hatexplain'].map(label_mapping)
df['distilroberta_numeric'] = df['distilroberta'].map(label_mapping)

# Calculate accuracy for facebook_roberta, hatexplain, and distilroberta
accuracy_hatexplain = accuracy_score(df['true_label'], df['hatexplain_numeric'])
accuracy_distilroberta = accuracy_score(df['true_label'], df['distilroberta_numeric'])

# Calculate F1 Scores (macro-averaged to account for multiple classes)
f1_hatexplain = f1_score(df['true_label'], df['hatexplain_numeric'], average='macro')
f1_distilroberta = f1_score(df['true_label'], df['distilroberta_numeric'], average='macro')

# Print Accuracy and F1 Scores
print(f"HateXplain - Accuracy: {accuracy_hatexplain}, F1 Score: {f1_hatexplain}")
print(f"DistilRoberta - Accuracy: {accuracy_distilroberta}, F1 Score: {f1_distilroberta}")

# Confusion Matrix for hatexplain
cm_hatexplain = confusion_matrix(df['true_label'], df['hatexplain_numeric'])
sns.heatmap(cm_hatexplain, annot=True, fmt="d", cmap="Blues", xticklabels=label_mapping.keys(), yticklabels=label_mapping.keys())
plt.title("Confusion Matrix: HateXplain")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Confusion Matrix for distilroberta
cm_distilroberta = confusion_matrix(df['true_label'], df['distilroberta_numeric'])
sns.heatmap(cm_distilroberta, annot=True, fmt="d", cmap="Blues", xticklabels=label_mapping.keys(), yticklabels=label_mapping.keys())
plt.title("Confusion Matrix: DistilRoberta")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()


# df['true_label'] = df['label'].map(label_mapping)
df['facebook_roberta_numeric'] = df['facebook_roberta'].map(label_mapping)
df['dehatebert_numeric'] = df['dehatebert'].map(label_mapping)
#accuracy
accuracy_facebook = accuracy_score(df['true_label'], df['facebook_roberta_numeric'])
accuracy_dehatebert = accuracy_score(df['true_label'], df['dehatebert_numeric'])

#F1
f1_facebook = f1_score(df['true_label'], df['facebook_roberta_numeric'], average='macro')
f1_dehatebert = f1_score(df['true_label'], df['dehatebert_numeric'], average='macro')
#Print scores
print(f"Facebook Roberta - Accuracy: {accuracy_facebook}, F1 Score: {f1_facebook}")
print(f"Dehatebert - Accuracy: {accuracy_dehatebert}, F1 Score: {f1_dehatebert}")

# Confusion Matrix for facebook_roberta
cm_facebook = confusion_matrix(df['true_label'], df['facebook_roberta_numeric'])
sns.heatmap(cm_facebook, annot=True, fmt="d", cmap="Blues", xticklabels=label_mapping.keys(), yticklabels=label_mapping.keys())
plt.title("Confusion Matrix: Facebook Roberta")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Confusion Matrix for dehatebert
cm_dehatebert = confusion_matrix(df['true_label'], df['dehatebert_numeric'])
sns.heatmap(cm_dehatebert, annot=True, fmt="d", cmap="Blues", xticklabels=label_mapping.keys(), yticklabels=label_mapping.keys())
plt.title("Confusion Matrix: Dehatebert")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# HateXplain - Accuracy: 0.6014778325123152, F1 Score: 0.5623473830837498
# DistilRoberta - Accuracy: 0.5822660098522168, F1 Score: 0.5733163067014602
# Facebook Roberta - Accuracy: 0.7527093596059113, F1 Score: 0.7524315667851232
# Dehatebert - Accuracy: 0.6019704433497537, F1 Score: 0.5719016478330953

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame and you want to simplify cardiff_roberta labels

# Mapping for cardiff_roberta, collapsing all hate categories into 'Hate'
label_mapping_cardiff = {
    "hate_gender": "Hate",
    "hate_race": "Hate",
    "hate_sexuality": "Hate",
    "hate_religion": "Hate",
    "hate_origin": "Hate",
    "hate_disability": "Hate",
    "hate_age": "Hate",
    "Neutral": "Neutral"
}

# Convert the 'cardiff_roberta' column to the new simplified label mapping
df['cardiff_roberta_simplified'] = df['cardiff_roberta'].map(label_mapping_cardiff)

# Convert the simplified labels to numeric values using the same mapping as before
label_mapping = {'Hate': 0,'Neutral': 1}

# Map the simplified labels to numeric values
df['cardiff_roberta_numeric'] = df['cardiff_roberta_simplified'].map(label_mapping)

# Calculate accuracy, F1 score, and confusion matrix
accuracy_cardiff = accuracy_score(df['true_label'], df['cardiff_roberta_numeric'])
f1_cardiff = f1_score(df['true_label'], df['cardiff_roberta_numeric'], average='macro')

# Print accuracy and F1 score
print(f"Cardiff Roberta (simplified) - Accuracy: {accuracy_cardiff}, F1 Score: {f1_cardiff}")

# Confusion Matrix for cardiff_roberta
cm_cardiff = confusion_matrix(df['true_label'], df['cardiff_roberta_numeric'])
sns.heatmap(cm_cardiff, annot=True, fmt="d", cmap="Blues", xticklabels=['Hate', 'Neutral'], yticklabels=['Hate', 'Neutral'])
plt.title("Confusion Matrix: Cardiff Roberta (simplified)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Cardiff Roberta (simplified) - Accuracy: 0.5635467980295567, F1 Score: 0.49455373201438846
